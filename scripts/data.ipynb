# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

# %%
import wrapper

olis = wrapper.OlisAPI()
current_session = olis.get_current_session()
current_session
# Out:
# {'odata.metadata': 'https://api.oregonlegislature.gov/odata/ODataService.svc/$metadata#LegislativeSessions',
#  'value': [{'Committees': [{'SessionKey': '2025R1',
#      'CommitteeCode': 'HALNRW',
#      'CommitteeName': 'Agriculture, Land Use, Natural Resources, and Water',
#      'HouseOfAction': 'H',
#      'CommitteeType': 'House Committee On',
#      'OfficeAddress': '453',
#      'OfficePhone': '503-986-1511',
#      'FaxNumber': '503-364-0545',
#      'WebAddress': 'www.oregonlegislature.gov',
#      'EmailAddress': 'halnrw.exhibits@oregonlegislature.gov',
#      'ParentCommitteeCode': None,
#      'CreatedDate': '2024-12-30T13:49:42',
#      'ModifiedDate': '2025-01-13T10:17:22'},
#     {'SessionKey': '2025R1',
#      'CommitteeCode': 'HBHHC',
#      'CommitteeName': 'Behavioral Health and Health Care',
#      'HouseOfAction': 'H',
#      'CommitteeType': 'House Committee On',
#      'OfficeAddress': '453',
#      'OfficePhone': '503-986-1509',
# ...

# %% [markdown]
# Get legislators serving in current legislative session

# %%
legislators = current_session['value'][0]['Legislators']
legislators
# Out:
# [{'SessionKey': '2025R1',
#   'LegislatorCode': 'Rep Andersen',
#   'FirstName': 'Tom',
#   'LastName': 'Andersen',
#   'CapitolAddress': '900 Court St NE, H-479, Salem, OR, 97301',
#   'CapitolPhone': '503-986-1419',
#   'Title': 'Representative',
#   'Chamber': 'H',
#   'Party': 'Democrat',
#   'DistrictNumber': '19',
#   'EmailAddress': 'Rep.TomAndersen@oregonlegislature.gov',
#   'WebSiteUrl': 'https://www.oregonlegislature.gov/Andersen',
#   'CreatedDate': '2024-11-06T11:52:47',
#   'ModifiedDate': '2025-02-28T14:44:18'},
#  {'SessionKey': '2025R1',
#   'LegislatorCode': 'Rep Boice',
#   'FirstName': 'Court',
#   'LastName': 'Boice',
#   'CapitolAddress': '900 Court St NE, H-476, Salem, OR, 97301',
#   'CapitolPhone': '503-986-1401',
#   'Title': 'Representative',
#   'Chamber': 'H',
#   'Party': 'Republican',
#   'DistrictNumber': '1',
#   'EmailAddress': 'Rep.CourtBoice@oregonlegislature.gov',
#   'WebSiteUrl': 'https://www.oregonlegislature.gov/Boice',
# ...

# %%
len(legislators)
# Out:
# 89

# %%
legislator_codes = [legislator['LegislatorCode'] for legislator in legislators]
legislator_codes
# Out:
# ['Rep Andersen',
#  'Rep Boice',
#  'Rep Boshart Davis',
#  'Rep Bowman',
#  'Rep Breese-Iverson',
#  'Rep Cate',
#  'Rep Chaichi',
#  'Rep Chotzen',
#  'Rep Diehl',
#  'Rep Dobson',
#  'Rep Drazan',
#  'Rep Edwards',
#  'Rep Elmer',
#  'Rep Evans',
#  'Rep Fragala',
#  'Rep Gamba',
#  'Rep Gomberg',
#  'Rep Grayber',
#  'Rep Harbick',
#  'Rep Hartman',
#  'Rep Helfrich',
#  'Rep Helm',
#  'Rep Hudson',
#  'Rep Isadore',
#  'Rep Javadi',
#  'Rep Kropf',
#  'Rep Levy B',
#  'Rep Levy E',
#  'Rep Lewis',
#  'Rep Lively',
#  'Rep Mannix',
#  'Rep Marsh',
#  'Rep McDonald',
#  'Rep McIntire',
#  'Rep McLain',
#  'Rep Munoz',
#  'Rep Nathanson',
#  'Rep Nelson',
#  'Rep Neron',
#  'Rep Nguyen D',
#  'Rep Nguyen H',
#  'Rep Nosse',
#  'Rep Osborne',
#  'Rep Owens',
#  'Rep Pham H',
#  'Rep Reschke',
#  'Rep Ruiz',
#  'Rep Sanchez',
#  'Rep Scharf',
#  'Rep Skarlatos',
#  'Rep Smith G',
#  'Rep Sosa',
#  'Rep Speaker Fahey',
#  'Rep Tran',
#  'Rep Valderrama',
#  'Rep Wallan',
# ...
